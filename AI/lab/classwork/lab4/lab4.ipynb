# %% [markdown]
# # search algos
# ![image.png](image.png)

# %% [markdown]
# ## uninformed / blind search
# ### BFS and DFS
#
#
#
# | bfs | DFS |
# | :--- | :--- |
# | ![BFS](https://s3.stackabuse.com/media/articles/bfs-gif.gif) | ![DFS](https://s3.stackabuse.com/media/articles/dfs-gif.gif) |
#
# ### depth limited search (DLS)
#
# - perform dfs till `n` layer
#
# ### Iterative Deepening Search (IDS)
#
# - performs DLS with `n` increasing with each iteration, then performs BFS on that layer
#
# ![](ezgif-71ac6e083c5efeea.gif)
#
#
# - BFS but with stack

# %% [markdown]
# # TASK #1
# Convert the following searching algorithms into agent-based models:
#
# Depth-Limited Search (DLS): Implement as a Goal-Based Agent to explore the graph up to a specified depth limit.
#
# Uniform Cost Search (UCS): Implement as a Utility-Based Agent to find the goal with the minimum cost path.

# %%
class node:
  def __init__(self) -> None:
    self.data = 0
    self.L = node()
    self.R = node()

class queue:
  def __init__(self):
    self.values = []

  def enq(self,val):
    self.values.append(val)

  def deq(self):
    val = self.values[0]
    for i in range(len(self.values)):
      self.values[i] = self.values[i+1]

def dfs(root,target):
  if(root==target):
    return root

  return bfs(root.L,target)
  return bfs(root.R,target)

def bfs(root,target):
  if(root==target):
    return root

  # push all children to queue
  Q = queue()
  Q.enq(root.L)
  Q.enq(root.R)




def DLS(tree,n):

# %% [markdown]
# # TASK # 2
# Traveling Salesman Problem:
# Given a set of cities and distances between every pair of cities, the problem is to find the shortest possible route that visits every city exactly once and returns to the starting point. Like any problem, which can be optimized, there must be a cost function. In the context of TSP, total distance traveled must be reduced as much as possible.
# Consider the below matrix representing the distances (Cost) between the cities. Find the shortest possible route that visits every city exactly once and returns to the starting point.
#
# ![image.png](image-0.png)

# %% [markdown]
# # TASK # 3
#
# Implement Iterative deepening DFS  on graph and tree.

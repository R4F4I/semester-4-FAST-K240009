# %% [markdown]
# # OOP

# %% [markdown]
# ## Declaring a method / attribute

# %%
class myClass:
    x = 5 # attr
    def method(self): #method
        self.x=3 
obj = myClass()
print(obj.x)
obj.method()
print(obj.x)
# Out:
# 5
# 3

# %% [markdown]
# ### attrib types
#
# - class attribute
# - defined directly inside class, outside method

# %%
class Student:
        school = "abv high school"

s1 = Student()
print(s1.school)
s2 = Student()
print(s1.school)

# %% [markdown]
# - instance attribute
# - belongs to object

# %%
class Student:
    def __init__(self, )
